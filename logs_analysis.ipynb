# %%
import pandas as pd

# %%
events = pd.read_csv("events_ful.csv", header=None)
events.head()
# Out:
#           0         1           2     3          4   5        6  7
# 0  150-3302  order:UP  2012-03-05  user  Order: UP NaN  2859969  0
# 1  150-3302  order:DW  2011-07-19  user  Order: DW NaN  2859970  0
# 2  150-3302  order:IN  2011-05-04  user  Order: IN NaN  2859971  0
# 3  150-3302  order:NP  2015-07-01  user  Order: NP NaN  2859972  0
# 4  150-3302  order:UP  2013-08-20  user  Order: UP NaN  2859973  0

# %%
events.drop(5, axis=1, inplace=True)

# %%
events.columns = ['account', 'order', 'date', 'source', 'details', 'event', 'churn']
events.head()
# Out:
#     account     order        date source    details    event  churn
# 0  150-3302  order:UP  2012-03-05   user  Order: UP  2859969      0
# 1  150-3302  order:DW  2011-07-19   user  Order: DW  2859970      0
# 2  150-3302  order:IN  2011-05-04   user  Order: IN  2859971      0
# 3  150-3302  order:NP  2015-07-01   user  Order: NP  2859972      0
# 4  150-3302  order:UP  2013-08-20   user  Order: UP  2859973      0

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650734 entries, 0 to 650733
# Data columns (total 7 columns):
# account    650734 non-null object
# order      650734 non-null object
# date       650734 non-null object
# source     650734 non-null object
# details    650734 non-null object
# event      650734 non-null int64
# churn      650734 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 34.8+ MB

# %%
factors = pd.read_csv("two_month_factors_call_full.csv", delimiter=';')
factors.head()
# Out:
#    site_id  is_caller  account_number min  tenure  mop  ratechange  onetime  \
# 0      106          1          253301   A    2201  NaN         NaN      NaN
# 1      106          1          308402   A    1414  NaN         NaN      NaN
# 2      106          1          312402   A     -16  NaN         2.0      1.0
# 3      106          1          357903   A      84  1.0         NaN      NaN
# 4      106          1         9189403   A     861  NaN         NaN      NaN
#
#   recurring adjustments     ...     wot_di  wot_dw  wot_in wot_np  wot_rs  \
# 0    124.82         NaN     ...        NaN     NaN     NaN    NaN     NaN
# 1        70         NaN     ...        NaN     NaN     NaN    NaN     NaN
# 2       180           9     ...        NaN     NaN     NaN    2.0     NaN
# 3    430.89       27.29     ...        NaN     NaN     NaN    NaN     NaN
# 4      94.9         NaN     ...        NaN     NaN     NaN    NaN     NaN
#
#    wot_sr  wot_tc  wot_up       start_date    end_date
# ...

# %%
factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19280 entries, 0 to 19279
# Data columns (total 24 columns):
# site_id           19280 non-null int64
# is_caller         19280 non-null int64
# account_number    19280 non-null int64
# min               19280 non-null object
# tenure            19280 non-null int64
# mop               3752 non-null float64
# ratechange        1975 non-null float64
# onetime           3418 non-null float64
# recurring         13530 non-null object
# adjustments       5309 non-null object
# payments          11974 non-null object
# promo_start       2611 non-null float64
# promo_end         447 non-null float64
# account_id        8967 non-null object
# wot_di            365 non-null float64
# wot_dw            2354 non-null float64
# wot_in            2221 non-null float64
# wot_np            1828 non-null float64
# wot_rs            81 non-null float64
# wot_sr            2346 non-null float64
# wot_tc            2572 non-null float64
# ...

# %%
factors['min'].value_counts()
# Out:
# A    19280
# Name: min, dtype: int64

# %%
factors.is_caller.value_counts()
# Out:
# 0    9999
# 1    9281
# Name: is_caller, dtype: int64

# %%
# %matplotlib inline

# %%
factors.hist(figsize=[20, 20])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000290D45C0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002B078F98>]], dtype=object)

# %%
events.hist(figsize=[12, 6])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000002C87E5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002CA3C278>]], dtype=object)
